# %% [markdown]
# <a href="https://colab.research.google.com/github/majidraza1228/LLM_2025/blob/main/Deepseekr1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama import OllamaLLM

template = """qustion:  {question}
Answer: Let me think step by step """

prompt = ChatPromptTemplate.from_template(template)
model = OllamaLLM(model="deepseek-r1:7b")

chain = prompt | model

chain.invoke({"question": "what will happen if I multiply 100 by 0?"})

# pip install -U langchain-ollama
# ollama pull  deepseek-r1:7b
# ollama serve &
# curl https://ollama.ai//install.sh | sh
# Out:
# "<think>\nTo determine what happens when multiplying 100 by 0, let's follow these steps:\n\nFirstly, consider the multiplication of a non-zero number by zero. For example, any number multiplied by zero results in zero.\n\nApplying this to our case:\n\\[ 100 \\times 0 = 0 \\]\n\nTherefore, multiplying 100 by 0 yields 0.\n</think>\n\nSure, let's explore what happens when you multiply **100** by **0**. \n\n### Step-by-Step Explanation:\n\n1. **Understanding Multiplication by Zero**\n   \n   When any number is multiplied by zero, the result is always zero. This is a fundamental property of multiplication known as the **Multiplicative Property of Zero**.\n\n2. **Applying to the Given Numbers**\n   \n   \\[\n   100 \\times 0 = 0\n   \\]\n\n3. **Conclusion**\n   \n   Multiplying **100** by **0** results in:\n\n\\[\n\\boxed{0}\n\\]"
